# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(data.shape)
pd.set_option('display.max_columns', None)
data.head()
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
data.columns = data.columns.str.lower().str.replace(' ', '_')
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    number_of_policies     policy_type        policy renew_offer_type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   sales_channel  total_claim_amount  vehicle_class vehicle_size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
data.dtypes
data['effective_to_date'] = pd.to_datetime(data['effective_to_date'], format='%m/%d/%y')
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0        2011-02-24         Employed      F   56274      Suburban
# 1        2011-01-31       Unemployed      F       0      Suburban
# 2        2011-02-19         Employed      F   48767      Suburban
# 3        2011-01-20       Unemployed      M       0      Suburban
# 4        2011-02-03         Employed      M   43836         Rural
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    number_of_policies     policy_type        policy renew_offer_type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   sales_channel  total_claim_amount  vehicle_class vehicle_size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
numericals = data.select_dtypes(np.number)
numericals.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# 2                          0                   2          566.472247
# 3                          0                   7          529.881344
# 4                          0                   1          138.130879

# %%
def differentiate_cont_disc(numericals, threshold=10):
    discrete_vars = []
    continuous_vars = []
    for col in numericals.columns:
        unique_count = numericals[col].nunique()
        if unique_count <= threshold:
           discrete_vars.append(col)
        else: continuous_vars.append(col)
    continuous_df = numericals[continuous_vars]
    discrete_df = numericals[discrete_vars]

    return continuous_df, discrete_df

# %%
continuous_df, discrete_df = differentiate_cont_disc(numericals)

# %%
continuous_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       total_claim_amount
# 0             384.811147
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4             138.130879
# ...                  ...
# 9129          198.234764
# 9130          379.200000
# 9131          790.784983
# 9132          691.200000
# 9133          369.600000
#
# [9134 rows x 6 columns]

# %%
discrete_df
# Out:
#       number_of_open_complaints  number_of_policies
# 0                             0                   1
# 1                             0                   8
# 2                             0                   2
# 3                             0                   7
# 4                             0                   1
# ...                         ...                 ...
# 9129                          0                   2
# 9130                          0                   1
# 9131                          3                   2
# 9132                          0                   3
# 9133                          0                   1
#
# [9134 rows x 2 columns]

# %%
#X/y split
X = numericals.drop('total_claim_amount',axis=1)
y = numericals['total_claim_amount']

# %%
correlations_matrix = X.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()
#There's a weak positive correlation between monthly_premium_auto and customer_lifetime_value
#otherwise there's no significant correlation.

# %%
def plot_discrete_variables(discrete_df):
    for col in discrete_df.columns:
            sns.countplot(x=col, data=discrete_df)
            plt.ylabel("Count")
            plt.show()

# %%
plot_discrete_variables(discrete_df)
#we can see that the majority of customers has no open complaints

# %%
def plot_countinuous_variables(continuous_df):
    for col in continuous_df.columns:
            sns.histplot(x=col, data=continuous_df)
            plt.ylabel("Count")
            plt.show()

# %%
plot_countinuous_variables(continuous_df)

# %%
def plot_countinuous_box(continuous_df):
    for col in continuous_df.columns:
            sns.boxplot(x=continuous_df[col])
            plt.show()

# %%
plot_countinuous_box(continuous_df)

# %%
numericals[numericals['customer_lifetime_value']> 55000]
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 79                58166.55351   61321                   186
# 1974              74228.51604       0                   242
# 2908              58753.88046   24964                   185
# 3760              61850.18803       0                   238
# 4126              60556.19213       0                   204
# 4915              56675.93768   77237                   283
# 5279              66025.75407   33481                   188
# 5716              83325.38119   58958                   231
# 6252              73225.95652   39547                   202
# 6461              55277.44589   40740                   198
# 6584              58207.12842   29295                   219
# 7283              67907.27050   78310                   192
# 7303              64618.75715       0                   217
# 7556              57520.50151   48367                   161
# 8825              61134.68307       0                   198
#
#       months_since_last_claim  months_since_policy_inception  \
# 79                          0                             30
# 1974                        1                             34
# 2908                        0                             84
# 3760                       19                             29
# 4126                       35                             45
# 4915                       33                             93
# 5279                       28                             46
# 5716                       31                             74
# 6252                       11                             21
# 6461                       19                             60
# 6584                       25                             50
# 7283                       34                             18
# 7303                       14                             40
# 7556                       10                             34
# 8825                        2                             75
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 79                            1                   2          427.631210
# 1974                          0                   2         1742.400000
# 2908                          0                   2          888.000000
# 3760                          0                   2         1142.400000
# 4126                          0                   2          979.200000
# 4915                          0                   2         1358.400000
# 5279                          0                   2         1194.892002
# 5716                          0                   2         1108.800000
# 6252                          0                   2          969.600000
# 6461                          0                   2          950.400000
# 6584                          0                   2         1328.839129
# 7283                          1                   2          151.711475
# 7303                          1                   2         1562.400000
# 7556                          0                   2          772.800000
# 8825                          0                   2         2275.265075

# %%
numericals[numericals['total_claim_amount']> 2400]
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 888               8581.278701   27689                   239
# 4930             43217.216110   51504                   220
# 5074              9295.411150       0                   261
# 9049             32104.699570   89546                   266
#
#       months_since_last_claim  months_since_policy_inception  \
# 888                         0                             72
# 4930                       30                             99
# 5074                       33                             44
# 9049                        4                             18
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 888                           2                   1         2893.239678
# 4930                          0                   2         2552.343856
# 5074                          0                   1         2759.794354
# 9049                          1                   2         2452.894264

# %%
#we only have a few outliers (less than 20) so it won't affect the future model badly to drop them. so I will
numericals = numericals.drop(numericals[numericals['customer_lifetime_value']> 55000].index).reset_index(drop=True)
numericals = numericals.drop(numericals[numericals['total_claim_amount']> 2400].index).reset_index(drop=True)
numericals
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9110             23405.987980   71941                    73
# 9111              3096.511217   21604                    79
# 9112              8163.890428       0                    85
# 9113              7524.442436   21941                    96
# 9114              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9110                       18                             89
# 9111                       14                             28
# 9112                        9                             37
# 9113                       34                              3
# 9114                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9110                          0                   2          198.234764
# 9111                          0                   1          379.200000
# 9112                          3                   2          790.784983
# 9113                          0                   3          691.200000
# 9114                          0                   1          369.600000
#
# [9115 rows x 8 columns]

# %%
numericals.isnull().sum()
#we don't have null values yaay!
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %%
data.to_csv('numerical.csv', index=False)
